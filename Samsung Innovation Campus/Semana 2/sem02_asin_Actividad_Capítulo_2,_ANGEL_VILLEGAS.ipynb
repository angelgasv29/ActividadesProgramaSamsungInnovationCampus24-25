# %% [markdown]
# # Actividades Capítulo 2.
#
#
# # Concepto básico de programación e inicio en Python
#
# ## Resumen de actividades
#
# - **Unidad 10.** Tipos de datos lista y tupla Tipos de datos lista y tupla
# - **Unidad 11.** Tipos de datos de diccionario Tipos de datos de diccionario
# - **Unidad 12.** Tipos de datos de secuencia
# - **Unidad 13.** Listas 2D
# - **Unidad 14.** Método del diccionario-1
# - **Unidad 15.** Método del diccionario-2
# - **Unidad 16.** Establecer tipos de datos

# %% [markdown]
# # Actividad: Creación de una Base de Datos en Python
#
# ## Descripción
#
# A continuación debes crear una base de datos simple utilizando listas en Python. Una base de datos es una colección de datos organizados que se utilizan para almacenar y recuperar información. En este caso, simularemos una base de datos de estudiantes con información básica.
#
# ## Instrucciones
#
# 1. Crea un programa en Python que permita a los usuarios realizar las siguientes acciones:
#
#    a. Agregar un nuevo estudiante a la base de datos. Cada estudiante debe tener al menos un nombre, un número de identificación y una edad. Puedes utilizar una lista para almacenar estos datos.
#
#    b. Mostrar la lista de estudiantes en la base de datos.
#
#    c. Buscar un estudiante por su número de identificación y mostrar su información.
#
#    d. Actualizar la información de un estudiante existente en la base de datos.
#
#    e. Eliminar un estudiante de la base de datos.
#
# 2. Utiliza listas de Python para almacenar la información de los estudiantes. Por ejemplo, puedes crear una lista de diccionarios, donde cada diccionario representa un estudiante con sus datos.
#
# 3. Ofrece un menú interactivo que permita a los usuarios elegir las acciones que desean realizar en la base de datos.
#
# 4. Implementa la lógica necesaria para cada acción, como agregar, buscar, actualizar o eliminar estudiantes.
#
# ## Ejemplo de Base de Datos
#
# A continuación, se muestra un ejemplo de cómo podría verse una base de datos de estudiantes utilizando listas y diccionarios:
#
# ```python
# base_de_datos = [
#     {"nombre": "Juan", "id": 1, "edad": 20},
#     {"nombre": "María", "id": 2, "edad": 22},
#     {"nombre": "Carlos", "id": 3, "edad": 21}
# ]
#
# Desarrolle el código en la siguiente lista.

# %%
#Recuerde agregar comentarios donde se describa el funcionamiento de las diferentes secciones.

print("Bienvenido a la base de datos estudiantil: ")

dato1 = input("\nPara continuar por favor ingrese los siguientes datos a solicitarle: \nNombre:")
dato2 = int(input("Cedula: "))  #variable numerica entera para manipular la indetificación en formato numerico
dato3 = int(input("Edad: "))    #almacenar variable edad en dato3

estudiante = []                 #declarar como lista donde se almacenarán los datos del primer estudiante que se ingresará a la base de datos

basedatos = []                  #declara base de datos como lista

usuario = {}                    #declara diccionario para agrupar los datos de la primera funcionalidad del programa


info2 = [{"Nombre:": "Angel", "Cédula":29698892, "Edad":21}]  #Datos predeterminados de la base de datos
info3 = [{"Nombre:": "Julio", "Cédula":31154741, "Edad":19}]
info4 = [{"Nombre:": "Genesis", "Cédula":32547235, "Edad":19}]

basedatos = info2 + info3 + info4                             #concatenar esa información en la base de datos


if dato2 < 0 or dato2 < 10_000_000 or dato2 > 33_000_000:     #Evaluar la coherencia de los datos ingresados por el primer estudiante a ingresar a la base de datos
  dato2 = int(input("incorrecto, por favor, ingrese una cedula válida: ")) #numero de cedula a partir de lo 10.000.000

if dato3 >= 100 or dato3 < 18:                                #Edad mínima 18 y maxima 100
  dato3 = int(input("incorrecto, por favor, ingrese una edad valida: "))

if dato2 > 10_000_000 and dato2 < 33_000_000 and dato3 > 17 and dato3 < 100:
  estudiante1 = info1 = {"Nombre:":dato1, "Cédula":dato2, "Edad":dato3}
                                                              #último apartado de verificación para determinar que los datos cumplan las condiciones
                                                              # En caso de cumplirse, realizar la concatenación de dichos datos en un diccionario.
basedatos.append(info1)                                       #Para agregar los datos de ese diccionario a la base de datos.

print("\nMENU DE OPCIONES, ELIJA SEGÚN CORRESPONDA: ")
opcion = int(input("""
    1. Agregar a un nuevo estudiante a la base de datos:
    2. Mostrar a la lista de estudiantes a la base de datos:
    3. Buscar a un estudiante por su numero de cedula y ver información:
    4. Actualizar la información de un estudiante existente:
    5. Eliminar un estudiante de la base de datos:\n"""))

if opcion != 1 and opcion != 2 and opcion != 3 and opcion != 4 and opcion != 5:  #Para limitar que sólo se elija numeros del 1 al 5.
    print("Error, debe ingresar una de las opciones disponibles del 1 al 5")

elif opcion == 1:                                             #Opción para almacenar en variables la información del nuevo estudiante a agregar
  valor1 = input("Ingrese nombre: ")
  valor2 = int(input("Ingrese cédula: "))
  valor3 = int(input("Ingrese edad: " ))
                                                              #Para concatenar los datos de esas variables en el diccionario usuario vacio, creado al principio del programa
  usuario = { "Nombre": valor1, "Cédula": valor2, "Edad": valor3}
  basedatos.append(usuario)                                   #Para agregar ese diccionario a la base de datos
  for i in basedatos:
    print(i)

elif opcion == 2:                                             #Para imprimir los diccionarios de la base de datos de una forma legible a través del for
  for i in basedatos:
    print(i)

elif opcion == 3:
  busqueda = int(input("Ingrese la cédula del estudiante a Buscar:")) #almaceno como entero la cedula a buscar en la lista de diccionarios (base de datos)
  usuario_encontrado = None                                    # Se declara una variable vacia.

  for estudiantes in basedatos:                                # el interador estudiantes tomará por cada vuelta de base de datos sus valores
    if estudiantes["Cédula"] == busqueda:                      # Sí dicho interador coincide con el valor de "Cédula", de lo que se ingresó en busqueda
      usuario_encontrado = estudiantes                         # asignar por referencia lo interado por estudiantes en ese punto

  if usuario_encontrado:
    print(f"Datos del estudiante encontrado: {usuario_encontrado}")
  else:
    print(f"la cedula {busqueda} no fue encontrada.")

elif opcion == 4:                                              # Aplicar el mismo procedimiento para ubicar concretamente a ese estudiante
  busqueda = int(input("Ingrese la cédula del estudiante a modificar: "))
  usuario_encontrado = None

  for estudiantes in basedatos:                                #Recorrer de la misma forma la lista de diccionario base de datos y ubicar dichos datos
    if estudiantes["Cédula"] == busqueda:
      usuario_encontrado = estudiantes
      break

  if usuario_encontrado:                                       #Para imprimir los datos de ese estudiante antes de modificar y modificar según sea necesario
    print(f"Datos actuales del estudiante: {usuario_encontrado}")
    nuevo_nombre = input("Ingrese el nuevo nombre o deje vacio para no modificar: ")
    nueva_edad = int(input("Ingrese la nueva edad o deje vacío: "))

    if nuevo_nombre:
      usuario_encontrado["Nombre:"] = nuevo_nombre             #Despues de almacenar y concatenar las variables en formato diccionario
    if nueva_edad:
      usuario_encontrado["Edad"] = nueva_edad

    print(f"Datos actualizados del estudiante: {usuario_encontrado}")
  else:
    print(f"la cédula {busqueda} no fue encontrada")

elif opcion == 5:                                              #Exactamente el mismo procedimiento para ubicar de forma precisa al estudiante a eliminar
  busqueda = int(input("Ingrese la cédula del estudiante a eliminar: "))
  usuario_encontrado = None

  for estudiantes in basedatos:
    if estudiantes["Cédula"] == busqueda:
      usuario_encontrado = estudiantes
      break
  if usuario_encontrado:                                      #Metodo .remove para eliminar dichos datos coincididos, de la base de datos
    basedatos.remove(usuario_encontrado)
    print(f"El estudiante con la cédula {busqueda} ha sido eliminado")
  else:
    print(f"La cédula {busqueda} no fue encontrada")
# Out:
# Bienvenido a la base de datos estudiantil:
#
# Para continuar por favor ingrese los siguientes datos a solicitarle:
# Nombre:angel
# Cedula: 29698893
# Edad: 28
#
# MENU DE OPCIONES, ELIJA SEGÚN CORRESPONDA:
#
#     1. Agregar a un nuevo estudiante a la base de datos:
#     2. Mostrar a la lista de estudiantes a la base de datos:
#     3. Buscar a un estudiante por su numero de cedula y ver información:
#     4. Actualizar la información de un estudiante existente:
#     5. Eliminar un estudiante de la base de datos:
# 4
# Ingrese la cédula del estudiante a modificar: 29698892
# Datos actuales del estudiante: {'Nombre:': 'Angel', 'Cédula': 29698892, 'Edad': 21}
# Ingrese el nuevo nombre o deje vacio para no modificar:
# Ingrese la nueva edad o deje vacío: 23
# Datos actualizados del estudiante: {'Nombre:': 'Angel', 'Cédula': 29698892, 'Edad': 23}

# %% [markdown]
# # Actividad: Rebanado de listas.
#
# Revisa la unidad 10,sección 5.3 aparece un resumen de los comandos para tomar secciones de una lista, aplica los comandos en la siguiente lista:
#
#
# list_notas = [15, 21, 24, 40, 13, 14, 18, 17, 14.5]

# %%
# Espacio para desarrollar las pruebas, si tienes alguna duda o comentario adicional
# lo puedes dejar planteado acá.

list_notas = [15, 21, 24, 40, 13, 14, 18, 17, 14.5]
print(list_notas[::2])

print(list_notas[2:5])

print(list_notas[:7])

print(list_notas[:])

print(list_notas[0:6:2])

print(list_notas[-3:])

print(list_notas[::-2])

print(list_notas[0::-2])
# Out:
# [15, 24, 13, 18, 14.5]
# [24, 40, 13]
# [15, 21, 24, 40, 13, 14, 18]
# [15, 21, 24, 40, 13, 14, 18, 17, 14.5]
# [15, 24, 13]
# [18, 17, 14.5]
# [14.5, 18, 13, 24, 15]
# [15]

# %% [markdown]
# # Actividad: Diferentes métodos usados en listas.
#
# De la unidad 10, sección 6.3 revise los métodos disponibles para usar sobre las listas.
#
# Aplique los métodos disponibles sobre la lista mostrada en la siguiente celda.
#
# Nota: usando el método **sort()** ordene de mayor a menor y viceversa (Si es necesario revise documentación adicional relacionada sobre este método)

# %%
# Aplique los métodos disponibles y agregue comentarios breves sobre su funcinamiento.

list_notas = [15, 21, 24, 40, 13, 14, 18, 13, 17, 14.5]

indice = list_notas.index(21) # Buscar en que indice de la lista aparece dicho número encerrado en parentesis


list_notas.append(50) #Agrega el número del parentesis al final de la lista, es decir desde último indice

print(list_notas.count(15)) #para contar cuantas veces aparece el número 15 dentro de la lista.


list_notas.insert(6, 22) # añadimos el 22 en la posicion 6
print(list_notas)


list_notas2 = [5, 8, 10, 11]

list_notas.extend(list_notas2) # incluye estos valores a la lista_notas2, a la lista original
print(list_notas)

# Espacio para desarrollo del código y comentarios.

list_notas.sort()  #para ordenar de menor a mayor
print(list_notas)

list_notas.sort(reverse = True) #para ordenar de mayor a menor
print(list_notas)
# Out:
# 1
# [15, 21, 24, 40, 13, 14, 22, 18, 13, 17, 14.5, 50]
# [15, 21, 24, 40, 13, 14, 22, 18, 13, 17, 14.5, 50, 5, 8, 10, 11]
# [5, 8, 10, 11, 13, 13, 14, 14.5, 15, 17, 18, 21, 22, 24, 40, 50]
# [50, 40, 24, 22, 21, 18, 17, 15, 14.5, 14, 13, 13, 11, 10, 8, 5]

# %% [markdown]
# # Actividad: Crear diccionarios y guardarlos como archivo JSON.
#
# De la unidad 11 sección 4.6 revise el ejemplo mostrado.
#
# Genera un diccionario, sobre la información que deseas guardar como base de datos, desarrollo el código necesario para generar el archivo JSON, y también el código para cargar la información del archivo JSON.

# %%
# Espacio para desarrollar el código.
import json

libros = {
    "1": {
        "titulo": "Cien años de soledad",
        "autor": "Gabriel García Márquez",
        "anio_publicacion": 1967,
        "genero": "Ficción"
    }
    }

with open('libros.json', 'w') as f:
    json.dump(libros, f, indent='\t')


with open('libros.json', 'r') as f:  # Cargar el diccionario desde el archivo JSON
    libros_cargados = json.load(f)


print(libros_cargados) # Mostrar la información cargada
# Out:
# {'1': {'titulo': 'Cien años de soledad', 'autor': 'Gabriel García Márquez', 'anio_publicacion': 1967, 'genero': 'Ficción'}}

# %% [markdown]
# # Actividad: Creación y manejo de tuplas.
#
# ## Instrucciones
#
# 1. Escriba una diferencia entre las tuplas y las listas.
# 2. Crear una tupla con varios elementos.
# 3. Usar el operador in para verificar si la tuple contiene determinado elemento.

# %%
# Espacio para desarrollar el código siguiendo las instrucciones.

tup = (1, 2, 3, 4, 5)

tupla2 = (10, 20, 30, 40, 50)

# La principal diferencia es a nivel de utilidad, a la misma no pueden modificarsele sus valores
# es decir es inmmutable, sin embargo a la lista sí. Aunque es importe destacar que podemos transformar
# una tupla en una lista

print(5 in tup)
# Out:
# True

# %% [markdown]
# # Actividad: Revisión y manejo de listas bidimensionales.
#
# ## Instrucciones
#
# 1. Describa brevemente que entiende por lista bidimensional.
# 2. Crear una lista bidimensional.
# 3. Generar un doble loop para acceder de la lista bidimensional
# 4. Sumar todo los elementos de esta lista bidimensional.

# %%
# Espacio para desarrollar el código, escriba comentarias breves para explicar su funcionamiento.

#Una lista bidimensional, también conocida como matriz es un estructura de que organiza los elementos en filas y columnas,
# es decir, que se puede visualizar como una tabla.

matriz = [
    [1, 2, 3],
    [4, 5, 6]
]
suma = 0

for fila in matriz:
    for elemento in fila:
        suma += elemento

print(suma)
# Out:
# 21

# %% [markdown]
# # Actividad: Revision de los métodos usados en el manejo de diccionarios.
#
# ## Instrucciones
#
# 1. Crear un diccionario.
# 2. Testear los siguientes métodos para el majeo de diccionarios get(), keys(), values(), items(), pop(), clear()
# 3. Agregar un breve comentario sobre su funcionamiento.

# %%
# Espacio para desarrollar el código.

contactos = {
    "Julio":{
        "nombre":"Julio Zambrano",
        "telefono":"0424-1880405",
        "correo":"juliozambranocl@gmail.com"
    },

    "Angel":{
        "nombre":"Angel Villegas",
        "telefono":"0414-9876543",
        "correo":"angel@correo.com"
    },

    "Genesis":{
        "nombre":"Genesis Escarlata",
        "telefono":"0426-1234567",
        "correo":"genesis@correo.com"
    }
}


contactos.get("Julio") # obtenermos la informacion solicitada mediante una key
print("get --> ", contactos.get("Julio"), "\n")

contactos.keys()
print("keys --> ",contactos.keys(), "\n") #obtiene todas las keys de un diccionario

contactos.values()
print("values --> ",contactos.values(), "\n") #obtiene todo los valores de un diccionario , tanto como su key y valores

contactos.items()
print("items --> ",contactos.items(), "\n") #engloba en una tupla cada elemento del diccionario

print("Pop --> ",contactos.pop("Angel"), "\n") #elimina el dato proporcionado del diccionario
print("Diccionario Nuevo --> ",contactos, "\n")

print("clear --> ",contactos.clear(), "\n") #elimina todos los datos del diccionario
